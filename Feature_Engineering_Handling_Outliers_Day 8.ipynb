# %% [markdown]
# ### Discussion Related With Outliers And Impact On Machine Learning!!

# %% [markdown]
# **Which all machine learning algorithms sensitive to outliers?**
#
# 1. `Naive Bayes` - Not sensitive to outliers
# 2. `SVM` - Sensitive to ouliers
# 3. `Linear Regression` - Sensitive to outliers
# 4. `Logistic Regression`- Sensitive to outliers
# 5. `Decision Tree` - Not sensitive to outliers
# 6. `Random Forest` - Not sensitive to outliers
# 7. `KNN` - Sensitive to outliers
# 8. `KMeans` - Sensitive to outliers
# 9. `Hierarichal Clustering` - Sensitive to outliers
# 10. `PCA` - Sensitive to outliers
# 11. `Neural Network` - Sensitive to outliers
# 12. `DBSCAN` - Not Sensitive to outliers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Z-Score Outlier Detection Method

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\saura\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df["Age"].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df["Age"])
# Out:
# C:\Users\saura\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# `Note`: Assuming Age column follows Gaussian Distribution

# %% [markdown]
# **Approach 1**

# %%
upper = df["Age"].mean() + 3 * df["Age"].std()
lower = df["Age"].mean() - 3 * df["Age"].std()

# %%
upper
# Out:
# 73.27860964406095

# %%
lower
# Out:
# -13.88037434994331

# %%
# finding the outliers
df[(df["Age"]<lower) | (df["Age"]>upper)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S

# %%
# Trimming
new_df = df[(df["Age"]>lower) & (df["Age"]<upper)]
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Approach 2:**

# %%
df["Age_zscore"] = (df["Age"] - df["Age"].mean())/df["Age"].std()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_zscore
# 0      0         A/5 21171   7.2500   NaN        S   -0.530005
# 1      0          PC 17599  71.2833   C85        C    0.571430
# 2      0  STON/O2. 3101282   7.9250   NaN        S   -0.254646
# ...

# %%
df[df["Age_zscore"]>3]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked  Age_zscore
# 630  male  80.0      0      0   27042  30.000   A23        S    3.462699
# 851  male  74.0      0      0  347060   7.775   NaN        S    3.049660

# %%
df[df["Age_zscore"]<-3]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Age_zscore]
# Index: []

# %%
df[(df["Age_zscore"]>3) | (df["Age_zscore"]<-3)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked  Age_zscore
# 630  male  80.0      0      0   27042  30.000   A23        S    3.462699
# 851  male  74.0      0      0  347060   7.775   NaN        S    3.049660

# %%
# trimming
new_df = df[(df["Age_zscore"]<3) & (df["Age_zscore"]>-3)]
new_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Approach 3:**

# %%
upper = df["Age"].mean() + 3 * df["Age"].std()
lower = df["Age"].mean() - 3 * df["Age"].std()

# %%
upper,lower
# Out:
# (73.27860964406095, -13.88037434994331)

# %%
df["Age"] = np.where(df["Age"]>upper,upper,
                    np.where(df["Age"]<lower,lower,df["Age"]))

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.688694
# std       14.492933
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       73.278610
# Name: Age, dtype: float64

# %% [markdown]
# ### IQR Method

# %% [markdown]
# `Note`: Used for skewed distribution

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.hist(df["Fare"])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
df["Fare"].skew()
# Out:
# 4.787316519674893

# %%
sns.boxplot(df["Fare"])
# Out:
# C:\Users\saura\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
q3 = df["Fare"].quantile(0.75)
q1 = df["Fare"].quantile(0.25)

# %%
iqr = q3 - q1
iqr
# Out:
# 23.0896

# %%
# For normal outliers
print("q1:",q1 - 1.5*iqr)
print("q3:",q3 + 1.5*iqr)
# Out:
# q1: -26.724
# q3: 65.6344

# %%
# For extreme outliers
print("q1:",q1 - 3*iqr)
print("q3:",q3 + 3*iqr)
# Out:
# q1: -61.358399999999996
# q3: 100.2688

# %%
upper_fence = q3 + 3*iqr
lower_fence = q1 - 3*iqr

# %%
# finding outliers
df[(df["Fare"]<lower_fence) | (df["Fare"]>upper_fence)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
# trimming
df_no_outliers = df[(df["Fare"]>lower_fence) & (df["Fare"]<upper_fence)]
df_no_outliers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Capping
new_df_cap = df.copy()
new_df_cap["Fare"] = np.where(new_df_cap["Fare"]>upper_fence,upper_fence,
                    np.where(new_df_cap["Fare"]<lower_fence,lower_fence,new_df_cap["Fare"]))

# %%
new_df_cap["Fare"].describe()
# Out:
# count    891.000000
# mean      27.043158
# std       27.339465
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      100.268800
# Name: Fare, dtype: float64

# %% [markdown]
# ### Testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df_no_outliers[['Age','Fare']].fillna(0),df_no_outliers['Survived'],test_size=0.3)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
y_pred1=classifier.predict_proba(X_test)

from sklearn.metrics import accuracy_score,roc_auc_score
print("Accuracy_score: {}".format(accuracy_score(y_test,y_pred)))
print("roc_auc_score: {}".format(roc_auc_score(y_test,y_pred1[:,1])))
# Out:
# Accuracy_score: 0.6904761904761905
# roc_auc_score: 0.6967326118425587

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier()
rf_classifier.fit(X_train,y_train)
y_pred=rf_classifier.predict(X_test)
y_pred1=rf_classifier.predict_proba(X_test)

from sklearn.metrics import accuracy_score,roc_auc_score
print("Accuracy_score: {}".format(accuracy_score(y_test,y_pred)))
print("roc_auc_score: {}".format(roc_auc_score(y_test,y_pred1[:,1])))
# Out:
# Accuracy_score: 0.6865079365079365
# roc_auc_score: 0.7341628179499551
